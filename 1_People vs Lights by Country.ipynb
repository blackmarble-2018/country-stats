# %% [markdown]
# # Comparing zonal stats for people vs lights by country

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# Plotly for interactive plotting
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %matplotlib inline

# %% [markdown]
# Used QGIS to do zonal stats using Natural Earth countries shapefile and both the lights and people rasters:

# %%
geodf = gpd.read_file('countries_with_population.geojson')

# %% [markdown]
# View the data.

# %%
geodf.head()
# Out:
#   fid  scalerank       featurecla  LABELRANK            SOVEREIGNT SOV_A3  \
# 0   1          1  Admin-0 country        3.0           Afghanistan    AFG
# 1   2          1  Admin-0 country        3.0                Angola    AGO
# 2   3          1  Admin-0 country        6.0               Albania    ALB
# 3   4          1  Admin-0 country        4.0  United Arab Emirates    ARE
# 4   5          1  Admin-0 country        2.0             Argentina    ARG
#
#    ADM0_DIF  LEVEL               TYPE                 ADMIN  \
# 0       0.0    2.0  Sovereign country           Afghanistan
# 1       0.0    2.0  Sovereign country                Angola
# 2       0.0    2.0  Sovereign country               Albania
# 3       0.0    2.0  Sovereign country  United Arab Emirates
# 4       0.0    2.0  Sovereign country             Argentina
#
#                          ...                         MIN_ZOOM  MIN_LABEL  \
# 0                        ...                              0.0        3.0
# 1                        ...                              0.0        3.0
# 2                        ...                              0.0        5.0
# 3                        ...                              0.0        4.0
# 4                        ...                              0.0        2.0
#
#   MAX_LABEL           sum       GPW        BM_sum     BM        area  \
# 0       7.0  2.754120e+07  27541201   2014.200038   2014   63.593500
# 1       7.0  2.552442e+07  25524423   3829.611838   3830  103.599439
# 2      10.0  2.766172e+06   2766172   1030.054924   1030    3.185163
# 3       9.0  6.786466e+06   6786466  14241.623780  14242    7.095047
# 4       7.0  4.217470e+07  42174700  36244.898752  36245  278.923392
#
#     perimeter                                           geometry
# 0   46.043309  (POLYGON ((61.21081709172574 35.65007233330923...
# 1   54.986811  (POLYGON ((23.90415368011818 -11.7222815894063...
# 2    8.146598  (POLYGON ((21.0200403174764 40.84272695572588,...
# 3   14.574017  (POLYGON ((51.57951867046327 24.24549713795111...
# 4  113.624468  (POLYGON ((-66.95992 -54.89681, -67.56244 -54....
#
# [5 rows x 79 columns]

# %% [markdown]
# # Absolute population by country

# %%
f, ax = plt.subplots(1, figsize=(20,10))
geodf.plot(ax=ax, linewidth=0, column="sum", cmap="Reds", scheme='fisher_jenks', legend=True)
ax.set_axis_off()
plt.axis('equal');

# %% [markdown]
# # Absolute night light luminosity per country

# %%
f, ax = plt.subplots(1, figsize=(20,10))
geodf.plot(ax=ax, linewidth=0, column="BM_sum", cmap="Blues", scheme='fisher_jenks', legend=True)
ax.set_axis_off()
plt.axis('equal');

# %% [markdown]
# # Calculate lights per capita

# %%
geodf['lights_per_capita'] = geodf['BM_sum'] / geodf['sum']

# %%
geodf.head()
# Out:
#   fid  scalerank       featurecla  LABELRANK            SOVEREIGNT SOV_A3  \
# 0   1          1  Admin-0 country        3.0           Afghanistan    AFG
# 1   2          1  Admin-0 country        3.0                Angola    AGO
# 2   3          1  Admin-0 country        6.0               Albania    ALB
# 3   4          1  Admin-0 country        4.0  United Arab Emirates    ARE
# 4   5          1  Admin-0 country        2.0             Argentina    ARG
#
#    ADM0_DIF  LEVEL               TYPE                 ADMIN        ...         \
# 0       0.0    2.0  Sovereign country           Afghanistan        ...
# 1       0.0    2.0  Sovereign country                Angola        ...
# 2       0.0    2.0  Sovereign country               Albania        ...
# 3       0.0    2.0  Sovereign country  United Arab Emirates        ...
# 4       0.0    2.0  Sovereign country             Argentina        ...
#
#   MIN_LABEL  MAX_LABEL           sum       GPW        BM_sum     BM  \
# 0       3.0        7.0  2.754120e+07  27541201   2014.200038   2014
# 1       3.0        7.0  2.552442e+07  25524423   3829.611838   3830
# 2       5.0       10.0  2.766172e+06   2766172   1030.054924   1030
# 3       4.0        9.0  6.786466e+06   6786466  14241.623780  14242
# 4       2.0        7.0  4.217470e+07  42174700  36244.898752  36245
#
#          area   perimeter                                           geometry  \
# 0   63.593500   46.043309  (POLYGON ((61.21081709172574 35.65007233330923...
# 1  103.599439   54.986811  (POLYGON ((23.90415368011818 -11.7222815894063...
# 2    3.185163    8.146598  (POLYGON ((21.0200403174764 40.84272695572588,...
# 3    7.095047   14.574017  (POLYGON ((51.57951867046327 24.24549713795111...
# 4  278.923392  113.624468  (POLYGON ((-66.95992 -54.89681, -67.56244 -54....
#
#   lights_per_capita
# 0          0.000073
# 1          0.000150
# 2          0.000372
# 3          0.002099
# 4          0.000859
#
# [5 rows x 80 columns]

# %% [markdown]
# # Lights vs. People (both on a linear scale)

# %% [markdown]
# Make scatter plot of people (horizontal axis) vs. lights (vertical axis).

# %%
people = geodf['sum']
lights = geodf['BM_sum']
labels = geodf['ADMIN']

# %%
fig, ax = plt.subplots(figsize=(18,10))
plt.scatter(people, lights, s=100, alpha=0.7)

# create dashed line from (0,0) to (max, max)
N = 100
x_ = np.linspace(0, people.max(), N)
y_ = np.linspace(0, lights.max(), N)
plt.plot(x_, y_, 'g--')

# annotate labels
horizontal_label_offset = 12000000
vertical_label_offset = -4000
for i, text in enumerate(labels):
    ax.annotate(text,
                (people[i]+horizontal_label_offset,
                 lights[i]-vertical_label_offset),
                fontsize=12)
    
# label the axes
plt.xlabel("People", fontsize=18)
plt.ylabel("Night Lights", fontsize=18);

# %% [markdown]
# # Lights (linear scale) vs People (log scale)

# %% [markdown]
# For more about the use of the log scale: https://en.wikipedia.org/wiki/Logarithmic_scale

# %% [markdown]
# Make an interactive scatter plot using a log scale on just the horizontal axis (people).

# %%
fig = {
    'data': [
        {
            'x': lights, 
            'y': people, 
            'text': labels, 
            'mode': 'markers'}
    ],
    'layout': {
        'xaxis': {'title': 'Population (Log Scale)', 'type': 'log'},
        'yaxis': {'title': "Night Lights", 'type': 'linear'}
    }
}

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~willgeary/267.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Lights vs. People (both on log scale)

# %% [markdown]
# Make an interactive scatter plot using a log scale on both the vertical axis (lights) and the horizontal axis (people).

# %%
fig = {
    'data': [
        {
            'x': lights, 
            'y': people, 
            'text': labels, 
            'mode': 'markers'}
    ],
    'layout': {
        'xaxis': {'title': 'Population (Log Scale)', 'type': 'log'},
        'yaxis': {'title': "Night Lights (Log Scale)", 'type': 'log'}
    }
}

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~willgeary/269.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Countries sorted by lights per capita

# %%
country_totals = pd.DataFrame()
country_totals['lights_per_capita'] = geodf['lights_per_capita']
country_totals.index = geodf['ADMIN']
del country_totals.index.name

# %%
country_totals.sort_values(by='lights_per_capita').plot(kind='barh', figsize=(6,60), title='Night Lights per Capita');
